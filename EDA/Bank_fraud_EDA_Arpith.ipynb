# %%
# !pip install opendatasets

# %%
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/sgpjesus/bank-account-fraud-dataset-neurips-2022/data")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: arpithshanbhag
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/sgpjesus/bank-account-fraud-dataset-neurips-2022

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/bank-account-fraud-dataset-neurips-2022/Base.csv")

# %%
data.head()
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.3               0.986506                         -1
# 1           0     0.8               0.617426                         -1
# 2           0     0.8               0.996707                          9
# 3           0     0.6               0.475100                         11
# 4           0     0.9               0.842307                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            25            40            0.006735
# 1                            89            20            0.010095
# 2                            14            40            0.012316
# 3                            14            30            0.006991
# 4                            29            40            5.742626
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  has_other_cards  \
# ...

# %%
data["fraud_bool"].value_counts()
data.dropna()
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0                0     0.3               0.986506                         -1
# 1                0     0.8               0.617426                         -1
# 2                0     0.8               0.996707                          9
# 3                0     0.6               0.475100                         11
# 4                0     0.9               0.842307                         -1
# ...            ...     ...                    ...                        ...
# 999995           0     0.8               0.124690                         -1
# 999996           0     0.9               0.824544                         -1
# 999997           0     0.8               0.140891                         -1
# 999998           0     0.9               0.002480                         52
# 999999           0     0.6               0.993391                         -1
#
# ...

# %%
data.columns
# Out:
# Index(['fraud_bool', 'income', 'name_email_similarity',
#        'prev_address_months_count', 'current_address_months_count',
#        'customer_age', 'days_since_request', 'intended_balcon_amount',
#        'payment_type', 'zip_count_4w', 'velocity_6h', 'velocity_24h',
#        'velocity_4w', 'bank_branch_count_8w',
#        'date_of_birth_distinct_emails_4w', 'employment_status',
#        'credit_risk_score', 'email_is_free', 'housing_status',
#        'phone_home_valid', 'phone_mobile_valid', 'bank_months_count',
#        'has_other_cards', 'proposed_credit_limit', 'foreign_request', 'source',
#        'session_length_in_minutes', 'device_os', 'keep_alive_session',
#        'device_distinct_emails_8w', 'device_fraud_count', 'month'],
#       dtype='object')

# %%
features = ['income', 'name_email_similarity',
       'prev_address_months_count', 'current_address_months_count',
       'customer_age', 'days_since_request', 'intended_balcon_amount',
       'payment_type', 'zip_count_4w', 'velocity_6h', 'velocity_24h',
       'velocity_4w', 'bank_branch_count_8w',
       'date_of_birth_distinct_emails_4w', 'employment_status',
       'credit_risk_score', 'email_is_free', 'housing_status',
       'phone_home_valid', 'phone_mobile_valid', 'bank_months_count',
       'has_other_cards', 'proposed_credit_limit', 'foreign_request', 'source',
       'session_length_in_minutes', 'device_os', 'keep_alive_session',
       'device_distinct_emails_8w', 'device_fraud_count', 'month']

# %%
plt.figure(figsize=(8,5))

for i, col in enumerate(features,1):
    plt.hist(data.loc[data.fraud_bool==0, col].sample(n=11000, random_state=52),
                color='blue',
                alpha=.4,
                label="Not Fraud")

    plt.hist(data.loc[data.fraud_bool==1, col].values,
                color='red',
                alpha=.4,
                hatch = '\\',
                edgecolor='black',
                label="Fraud")

    plt.xlabel(col)
    plt.legend()
    plt.show()

# %% [markdown]
# There isn't a feature that separates Fraud/Not-Fraud well enough but a few features to consider:
#
# 1. income
# 2. customer age
# 3. credit_risk_score
# 4. keep_alive_session
# 5. device_os

# %%
sampled_data = pd.concat([data.loc[data.fraud_bool == 0].sample(n = 11000, random_state = 42), data.loc[data.fraud_bool == 1]], axis = 0)
sampled_data.head()
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 518794           0     0.8               0.735925                        104
# 567631           0     0.9               0.313330                         -1
# 269688           0     0.1               0.129044                         -1
# 375838           0     0.9               0.071233                         -1
# 558695           0     0.1               0.920019                         62
#
#         current_address_months_count  customer_age  days_since_request  \
# 518794                            10            30            0.030076
# 567631                            30            30            0.002789
# 269688                           238            20            0.013602
# 375838                            65            30            0.005794
# 558695                            13            30            0.018723
#
#         intended_balcon_amount payment_type  zip_count_4w  ...  \
# ...

# %%
#Let's check the correlation between these
fin_feat = ['income',
       'customer_age',
       'credit_risk_score', 'keep_alive_session']


sns.pairplot(data=sampled_data, x_vars = fin_feat, y_vars = fin_feat , plot_kws = {'alpha':.4}, hue = 'fraud_bool')

plt.show()
